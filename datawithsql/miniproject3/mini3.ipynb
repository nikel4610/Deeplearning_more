# %%
import pandas as pd
import chart_studio.plotly as py
import cufflinks as cf
import plotly.express as px
import plotly.graph_objects as go
cf.go_offline(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
wine = pd.read_csv('D:/vsc_project/Deeplearning_more/WineQT.csv')
wine.head()

# fixed.acidity(결합산) : 와인의 산도를 제어한다. 
# volatile.acidity(휘발산) : 와인의 향에 연관이 많다. 
# citric.acid(구연산) : 와인의 신선함을 유지시켜주는 역할을 하며, 산성화에 연관을 미친다. 
# residual.sugar(잔여 설탕) : 와인의 단맛을 올려준다. 
# chlorides(염소) : 와인의 짠맛과 신맛을 좌우하는 성분이다. 
# free.sulfur.dioxide / total.sulfur.dioxide / sulphates(황 화합물) : 특정 박테리아와 효모를 죽여 와인의 보관도를 높여준다. 
# density(밀도) : 바디의 높고 낮음을 표현하는 와인의 바디감을 의미한다. 
# pH(산성도) : 와인의 신맛의 정도를 나타낸다. 
# alcohol(알코올) : 와인에 단맛을 주며 바디감에 영향을 준다. 
# quality(퀄리티) : 결과적으로 다른 변수들을 이용하여 예측하려고 하는 변수로 와인의 퀄리티를 나타낸다.
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# ...

# %%
wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# ...

# %%
del wine['Id']
wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
# quality 순으로 정렬
wine = wine.sort_values(by='quality', ascending=False)
wine.head()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 197            10.3              0.32         0.45             6.4      0.073
# 349            10.7              0.35         0.53             2.6      0.070
# 1030            7.2              0.38         0.31             2.0      0.056
# 190             7.9              0.35         0.46             3.6      0.078
# 1104            7.4              0.36         0.30             1.8      0.074
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 197                   5.0                  13.0  0.99760  3.23       0.82
# 349                   5.0                  16.0  0.99720  3.15       0.65
# 1030                 15.0                  29.0  0.99472  3.23       0.76
# 190                  15.0                  37.0  0.99730  3.35       0.86
# 1104                 17.0                  24.0  0.99419  3.24       0.70
#
#       alcohol  quality
# 197      12.6        8
# ...

# %%
fig = px.pie(wine, values='quality', names='quality', title='Wine Quality')
fig.show()
# Out:
# <div>                            <div id="afa4de45-94a1-410e-994b-945293c593fb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("afa4de45-94a1-410e-994b-945293c593fb")) {                    Plotly.newPlot(                        "afa4de45-94a1-410e-994b-945293c593fb",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"quality=%{value}<extra></extra>","labels":[8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,6,6,6,6,6,6,6,6,6,6,6,6,6,6,6,6,6,6,6,6,6,6,6,6,6
# ...

# %%
df_corr_bar = abs(wine.corr()['quality']).sort_values()[:-1]
fig = px.bar(df_corr_bar, orientation='h', color_discrete_sequence =['#4285f4']*len(df_corr_bar))
fig.update_layout(showlegend=False)
fig.show()
# Out:
# <div>                            <div id="249462c7-07d5-4aa9-83f9-99ff1f6caf06" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("249462c7-07d5-4aa9-83f9-99ff1f6caf06")) {                    Plotly.newPlot(                        "249462c7-07d5-4aa9-83f9-99ff1f6caf06",                        [{"alignmentgroup":"True","hovertemplate":"variable=quality<br>value=%{x}<br>index=%{y}<extra></extra>","legendgroup":"quality","marker":{"color":"#4285f4","pattern":{"shape":""}},"name":"quality","offsetgroup":"quality","orientation":"h","showlegend":true,"textposition":"auto","x":[0.02200193057996762,0.05245303335786703,0.0632596414725385,0.12197009989725709,0.12408453132893017,0.17520792322646186,0.18333914747213026,0.24082083714719402,0.25771025993062263,0.407
# ...

# %%
fig = px.imshow(wine.corr(),color_continuous_scale="Blues", text_auto = True)
fig.update_layout(height=750)
fig.show()
# Out:
# <div>                            <div id="eb3dda30-5834-45f8-aeb8-fc0940ddaf5a" class="plotly-graph-div" style="height:750px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eb3dda30-5834-45f8-aeb8-fc0940ddaf5a")) {                    Plotly.newPlot(                        "eb3dda30-5834-45f8-aeb8-fc0940ddaf5a",                        [{"coloraxis":"coloraxis","name":"0","texttemplate":"%{z}","x":["fixed acidity","volatile acidity","citric acid","residual sugar","chlorides","free sulfur dioxide","total sulfur dioxide","density","pH","sulphates","alcohol","quality"],"y":["fixed acidity","volatile acidity","citric acid","residual sugar","chlorides","free sulfur dioxide","total sulfur dioxide","density","pH","sulphates","alcohol","quality"],"z":[[1.0,-0.25072832229222464,0.6731572507629217,0.17183
# ...

# %%
# quality 별 산도와 바디감, 도수의 상관관계 보여줌 / 원 크기는 신선함
fig3 = px.scatter(wine, x = 'fixed acidity', y = 'density', facet_col='quality', size = 'citric acid', color = 'alcohol')
fig3.show()
# Out:
# <div>                            <div id="cd49a47c-5e82-4c8a-80fd-812770b0620f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cd49a47c-5e82-4c8a-80fd-812770b0620f")) {                    Plotly.newPlot(                        "cd49a47c-5e82-4c8a-80fd-812770b0620f",                        [{"hovertemplate":"quality=8<br>fixed acidity=%{x}<br>density=%{y}<br>citric acid=%{marker.size}<br>alcohol=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[12.6,11.0,11.3,12.8,11.4,10.0,11.7,12.9,11.8,9.8,12.5,13.4,11.7,13.1,11.0,14.0],"coloraxis":"coloraxis","size":[0.45,0.53,0.31,0.46,0.3,0.33,0.39,0.05,0.54,0.72,0.5,0.67,0.56,0.34,0.53,0.24],"sizemode":"area","sizeref":0.0025,"symbol":"circle"},"mode":"markers","name":"","showlegend":false,"
# ...

# %%
wine_quality6 = wine[wine['quality'].between(5, 7)]
wine_quality6.head()
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 346            8.9              0.40         0.51             2.6      0.052
# 598            6.7              0.28         0.28             2.4      0.012
# 619            8.8              0.31         0.40             2.8      0.109
# 170           15.0              0.21         0.44             2.2      0.075
# 171           15.0              0.21         0.44             2.2      0.075
#
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 346                 13.0                  27.0  0.99500  3.32       0.90
# 598                 36.0                 100.0  0.99064  3.26       0.39
# 619                  7.0                  16.0  0.99614  3.31       0.79
# 170                 10.0                  24.0  1.00005  3.07       0.84
# 171                 10.0                  24.0  1.00005  3.07       0.84
#
#      alcohol  quality
# 346     13.4        7
# ...

# %%
# quality 별 산도와 바디감, 도수의 상관관계 보여줌 / 원 크기는 신선함
fig4 = px.scatter(wine_quality6, x = 'fixed acidity', y = 'density', facet_col='quality', size = 'citric acid', color = 'alcohol')
fig4.show()
# Out:
# <div>                            <div id="bc9d01c2-9280-46c9-878b-613749697373" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bc9d01c2-9280-46c9-878b-613749697373")) {                    Plotly.newPlot(                        "bc9d01c2-9280-46c9-878b-613749697373",                        [{"hovertemplate":"quality=7<br>fixed acidity=%{x}<br>density=%{y}<br>citric acid=%{marker.size}<br>alcohol=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[13.4,11.7,11.8,9.2,9.2,10.6,11.3,11.8,10.1,10.5,11.2,11.7,9.9,11.0,11.8,14.0,12.9,10.5,11.8,9.9,10.5,12.2,11.3,10.6,11.0,11.0,11.3,13.6,13.566666666666698,10.8,10.0,10.0,10.8,10.8,13.6,12.5,11.9,12.5,10.3,10.8,10.8,11.2,11.8,11.6,12.4,10.6,13.3,12.3,11.2,10.8,13.0,10.8,13.6,11.7,12.5,12.3,11
# ...

# %%
fig = px.scatter(wine, x = 'alcohol', y = 'residual sugar', color = 'quality', size = 'citric acid', height = 500, width = 500)
fig.show()
# Out:
# <div>                            <div id="2a93b92d-4757-4a7e-85cf-40ba95602639" class="plotly-graph-div" style="height:500px; width:500px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2a93b92d-4757-4a7e-85cf-40ba95602639")) {                    Plotly.newPlot(                        "2a93b92d-4757-4a7e-85cf-40ba95602639",                        [{"hovertemplate":"alcohol=%{x}<br>residual sugar=%{y}<br>citric acid=%{marker.size}<br>quality=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7
# ...

# %%
wine_flavor = wine[['alcohol', 'residual sugar', 'fixed acidity', 'citric acid', 'volatile acidity', 'quality']]
wine_flavor.head()
# Out:
#       alcohol  residual sugar  fixed acidity  citric acid  volatile acidity  \
# 197      12.6             6.4           10.3         0.45              0.32
# 349      11.0             2.6           10.7         0.53              0.35
# 1030     11.3             2.0            7.2         0.31              0.38
# 190      12.8             3.6            7.9         0.46              0.35
# 1104     11.4             1.8            7.4         0.30              0.36
#
#       quality
# 197         8
# 349         8
# 1030        8
# 190         8
# 1104        8

# %%
fig5 = px.bar(wine_quality6, x = 'residual sugar', y = 'fixed acidity', facet_col='quality', height = 500)
fig5.show()
# Out:
# <div>                            <div id="143c6855-3e38-46b0-b3b4-a19685b2865f" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("143c6855-3e38-46b0-b3b4-a19685b2865f")) {                    Plotly.newPlot(                        "143c6855-3e38-46b0-b3b4-a19685b2865f",                        [{"alignmentgroup":"True","hovertemplate":"quality=7<br>residual sugar=%{x}<br>fixed acidity=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[2.6,2.4,2.8,2.2,2.2,1.7,2.5,6.2,1.8,2.6,1.6,2.4,1.9,2.3,1.75,2.1,2.1,5.6,2.3,3.5,5.6,1.6,2.0,2.5,2.7,1.9,1.7,2.2,2.2,6.0,2.1,2.1,2.4,2.4,1.8,2.4,1.7,2.4,1.4,2.6,2.6,5.5,1.7,2.0,2.5,2.5,2.5,2.3,2
# ...

# %%
fig6 = px.bar(wine_quality6, x = 'residual sugar', y = 'fixed acidity', facet_col='quality', height = 500)
fig6.show()
# Out:
# <div>                            <div id="cb32be67-9ded-40f1-a585-02fcd5d3f371" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cb32be67-9ded-40f1-a585-02fcd5d3f371")) {                    Plotly.newPlot(                        "cb32be67-9ded-40f1-a585-02fcd5d3f371",                        [{"alignmentgroup":"True","hovertemplate":"quality=7<br>residual sugar=%{x}<br>fixed acidity=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[2.6,2.4,2.8,2.2,2.2,1.7,2.5,6.2,1.8,2.6,1.6,2.4,1.9,2.3,1.75,2.1,2.1,5.6,2.3,3.5,5.6,1.6,2.0,2.5,2.7,1.9,1.7,2.2,2.2,6.0,2.1,2.1,2.4,2.4,1.8,2.4,1.7,2.4,1.4,2.6,2.6,5.5,1.7,2.0,2.5,2.5,2.5,2.3,2
# ...

# %%
fig7 = px.bar(wine_quality6, x = 'total sulfur dioxide', y = 'free sulfur dioxide', facet_col='quality', height = 500)
fig7.show()
# Out:
# <div>                            <div id="3ed09262-1ff3-4cd0-b84c-7b28f78c5b4f" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3ed09262-1ff3-4cd0-b84c-7b28f78c5b4f")) {                    Plotly.newPlot(                        "3ed09262-1ff3-4cd0-b84c-7b28f78c5b4f",                        [{"alignmentgroup":"True","hovertemplate":"quality=7<br>total sulfur dioxide=%{x}<br>free sulfur dioxide=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[27.0,100.0,16.0,24.0,24.0,32.0,47.0,14.0,25.0,33.0,28.0,100.0,21.0,8.0,88.0,42.0,101.0,47.0,19.0,10.0,47.0,106.0,28.0,49.0,17.0,77.0,27.0,89.0,89.0,18.0,54.0,54.0,33.0,33.0,38.0,43.0
# ...
